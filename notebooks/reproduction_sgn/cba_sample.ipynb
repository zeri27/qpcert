# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os

current_working_directory = os.getcwd()
print(f"Current Working Directory: {current_working_directory}\n")
python_paths = sys.path
print("Python's Search Paths (sys.path):")
for path in python_paths:
    print(f"- {path}")

def prepare():
    # module_path = os.path.abspath(os.path.join('..'))
    module_path = os.path.abspath(os.path.join('../', '../'))
    if module_path not in sys.path:
        sys.path.append(module_path)

print(sys.path)
# Out:
# Current Working Directory: /mnt/c/Users/emiel/Documents/GitHub/victor/qpcert/notebooks/reproduction_sgn
#
# Python's Search Paths (sys.path):
# - /home/emiel00/miniconda3/envs/qpcert-env/lib/python311.zip
# - /home/emiel00/miniconda3/envs/qpcert-env/lib/python3.11
# - /home/emiel00/miniconda3/envs/qpcert-env/lib/python3.11/lib-dynload
# -
# - /home/emiel00/miniconda3/envs/qpcert-env/lib/python3.11/site-packages
# - /mnt/c/Users/emiel/Documents/GitHub/victor/qpcert
# - /home/emiel00/miniconda3/envs/qpcert-env/lib/python3.11/site-packages/setuptools/_vendor
# ['/home/emiel00/miniconda3/envs/qpcert-env/lib/python311.zip', '/home/emiel00/miniconda3/envs/qpcert-env/lib/python3.11', '/home/emiel00/miniconda3/envs/qpcert-env/lib/python3.11/lib-dynload', '', '/home/emiel00/miniconda3/envs/qpcert-env/lib/python3.11/site-packages', '/mnt/c/Users/emiel/Documents/GitHub/victor/qpcert', '/home/emiel00/miniconda3/envs/qpcert-env/lib/python3.11/site-packages/setuptools/_vendor']

# %%
import torch
import numpy as np
prepare()
from exp_labelcert_binaryclass import run

# %%
seeds = [0, 1, 2, 3, 4]
deltas = [0.00, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30]

# %%
model_params = dict(
    label = "SGC", 
    model = "GCN", 
    normalization = "row_normalization",
    activation = "linear",
    depth = 1,
    regularizer = 0.001,
    pred_method = "svm",
    bias = False,
    alpha_tol = 1e-4,
    solver = "qplayer",
)

certificate_params = dict(
    delta = 0.01,
    TimeLimit = 86400,
    LogToConsole = 1,
    OutputFlag = 1,
    Threads = 2,
    Presolve = 2
)

verbosity_params = dict(
    debug_lvl = "warning"
)  

other_params = dict(
    device = "0",
    dtype = torch.float64,
    allow_tf32 = False,
    path_gurobi_license="/mnt/c/Users/emiel/gurobi.lic"

)

# %%
data_params = dict(
    dataset = "cba",
    learning_setting = "transductive", 
    specification = dict(
        classes = 2,
        n_trn_labeled = 10,
        n_trn_unlabeled = 0,
        n_val = 10,
        n_test = 180,
        sigma = 1,
        avg_within_class_degree = 1.58 * 2,
        avg_between_class_degree = 0.37 * 2,
        K = 1.5,
        m = 2,
        # seed = 0 # used to generate the dataset & data split
    )
)

# %%
import pandas as pd
import time

metrics_to_log = ["accuracy_test", "accuracy_trn", "accuracy_cert_pois_robust", "delta", "runtime"]
output_base_dir = "results/samplewise"
os.makedirs(output_base_dir, exist_ok=True)

dataset_name = "cba"

for delta in deltas:
    certificate_params["delta"] = delta
    summary_results = []
    print(f"  Running for delta: {delta:.2f}")

    for seed in seeds:
        data_params["specification"]["seed"] = seed
        start_time = time.time()
        result = run(data_params=data_params, model_params=model_params,
                     certificate_params=certificate_params, verbosity_params=verbosity_params,
                     other_params=other_params, seed=seed)
        runtime = round(time.time() - start_time, 2)
        result['runtime'] = runtime
        summary_results.append({k: result.get(k) for k in metrics_to_log})

    df = pd.DataFrame(summary_results, index=[f"Seed {s}" for s in seeds])
    df.index.name = "seed"
    output_filename = f"{dataset_name}-{delta:.2f}.csv"
    output_path = os.path.join(output_base_dir, output_filename)
    df.to_csv(output_path, index=True)

    print(f"  Results saved to: {output_path}")
    print(df)
    print("-" * 30)
# Out:
#   Running for delta: 0.00
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0xc050ee0d
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 2161 rows and 740 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
#
# User-callback calls 158, time in user-callback 0.00 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0xd05df656
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 2161 rows and 740 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
#
# User-callback calls 158, time in user-callback 0.00 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0x573debfb
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 2161 rows and 740 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
#
# User-callback calls 158, time in user-callback 0.00 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0x8e24dbe3
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 2161 rows and 740 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
#
# User-callback calls 158, time in user-callback 0.00 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0xabef9ca0
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 2161 rows and 740 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
#
# User-callback calls 158, time in user-callback 0.00 sec
#   Results saved to: results/collective/cba-0.00.csv
#         accuracy_test  accuracy_trn  accuracy_cert_pois_robust delta  runtime
# seed
# Seed 0       0.883333          1.00                        1.0  None     0.12
# Seed 1       0.855556          0.90                        1.0  None     0.10
# Seed 2       0.827778          0.95                        1.0  None     0.11
# Seed 3       0.883333          1.00                        1.0  None     0.09
# Seed 4       0.855556          0.95                        1.0  None     0.09
# ------------------------------
#   Running for delta: 0.05
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0x34b7eb70
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 1946 rows and 518 columns
# Presolve time: 0.01s
# Presolved: 215 rows, 222 columns, 1094 nonzeros
# Variable types: 0 continuous, 222 integer (222 binary)
# Root relaxation presolved: 196 rows, 202 columns, 1012 nonzeros
#
#
# Root relaxation: objective 1.044357e+01, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   10.44357    0   12   -0.00000   10.44357      -     -    0s
# H    0     0                       3.0000000   10.44357   248%     -    0s
# H    0     0                       5.0000000   10.44357   109%     -    0s
# H    0     0                       6.0000000   10.44357  74.1%     -    0s
#      0     0   10.44357    0   12    6.00000   10.44357  74.1%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.03 seconds (0.03 work units)
# Thread count was 2 (of 24 available processors)
#
# Solution count 4: 6 5 3 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
#
# User-callback calls 437, time in user-callback 0.00 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0xf214a1ab
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 1908 rows and 499 columns
# Presolve time: 0.03s
# Presolved: 253 rows, 241 columns, 1892 nonzeros
# Variable types: 0 continuous, 241 integer (241 binary)
# Root relaxation presolved: 253 rows, 241 columns, 1892 nonzeros
#
#
# Root relaxation: objective 2.781147e+01, 69 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   27.81147    0   31   -0.00000   27.81147      -     -    0s
# H    0     0                       9.0000000   27.81147   209%     -    0s
# H    0     0                      14.0000000   27.81147  98.7%     -    0s
# *    0     0               0      15.0000000   15.00000  0.00%     -    0s
#
# Explored 1 nodes (69 simplex iterations) in 0.04 seconds (0.06 work units)
# Thread count was 2 (of 24 available processors)
#
# Solution count 4: 15 14 9 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
#
# User-callback calls 485, time in user-callback 0.00 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0x061ae0b2
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 1951 rows and 522 columns
# Presolve time: 0.03s
# Presolved: 210 rows, 218 columns, 1024 nonzeros
# Variable types: 0 continuous, 218 integer (218 binary)
# Root relaxation presolved: 210 rows, 218 columns, 1024 nonzeros
#
#
# Root relaxation: objective 9.184065e+00, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.18406    0   10   -0.00000    9.18406      -     -    0s
# H    0     0                       3.0000000    9.18406   206%     -    0s
# H    0     0                       7.0000000    9.18406  31.2%     -    0s
# H    0     0                       8.0000000    9.18406  14.8%     -    0s
# *    0     0               0       9.0000000    9.00000  0.00%     -    0s
#
# Explored 1 nodes (46 simplex iterations) in 0.04 seconds (0.05 work units)
# Thread count was 2 (of 24 available processors)
#
# Solution count 5: 9 8 7 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
#
# User-callback calls 656, time in user-callback 0.00 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0x9eb7e3a8
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 1948 rows and 519 columns
# Presolve time: 0.02s
# Presolved: 213 rows, 221 columns, 1052 nonzeros
# Variable types: 0 continuous, 221 integer (221 binary)
# Root relaxation presolved: 176 rows, 182 columns, 895 nonzeros
#
#
# Root relaxation: objective 9.768797e+00, 48 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.76880    0   11   -0.00000    9.76880      -     -    0s
# H    0     0                       4.0000000    9.76880   144%     -    0s
# H    0     0                       5.0000000    9.76880  95.4%     -    0s
# H    0     0                       8.0000000    9.76880  22.1%     -    0s
# *    0     0               0       9.0000000    9.00000  0.00%     -    0s
#
# Explored 1 nodes (49 simplex iterations) in 0.03 seconds (0.03 work units)
# Thread count was 2 (of 24 available processors)
#
# Solution count 5: 9 8 5 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
#
# User-callback calls 442, time in user-callback 0.00 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0xd148a678
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 1930 rows and 510 columns
# Presolve time: 0.02s
# Presolved: 231 rows, 230 columns, 1430 nonzeros
# Variable types: 0 continuous, 230 integer (230 binary)
# Root relaxation presolved: 231 rows, 230 columns, 1430 nonzeros
#
#
# Root relaxation: objective 2.000000e+01, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      20.0000000   20.00000  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.03 seconds (0.05 work units)
# Thread count was 2 (of 24 available processors)
#
# Solution count 2: 20 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
#
# User-callback calls 475, time in user-callback 0.00 sec
#   Results saved to: results/collective/cba-0.05.csv
#         accuracy_test  accuracy_trn  accuracy_cert_pois_robust delta  runtime
# seed
# Seed 0       0.883333          1.00                   0.966667  None     0.19
# Seed 1       0.855556          0.90                   0.916667  None     0.12
# Seed 2       0.827778          0.95                   0.950000  None     0.12
# Seed 3       0.883333          1.00                   0.950000  None     0.10
# Seed 4       0.855556          0.95                   0.888889  None     0.11
# ------------------------------
#   Running for delta: 0.10
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0xb5c6cf4a
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 280 rows and 160 columns
# Presolve time: 0.01s
# Presolved: 1881 rows, 580 columns, 12140 nonzeros
# Variable types: 380 continuous, 200 integer (200 binary)
# Root relaxation presolved: 1701 rows, 760 columns, 8540 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective
     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 42
#   Clique: 2
#   MIR: 44
#   StrongCG: 20
#   RLT: 1
#
# Explored 91 nodes (4795 simplex iterations) in 0.58 seconds (1.09 work units)
# Thread count was 2 (of 24 available processors)
#
# Solution count 6: 10 9 7 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
#
# User-callback calls 989, time in user-callback 0.00 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0xc3231067
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 280 rows and 160 columns
# Presolve time: 0.01s
# Presolved: 1881 rows, 580 columns, 12140 nonzeros
# Variable types: 380 continuous, 200 integer (200 binary)
# Root relaxation presolved: 1701 rows, 760 columns, 8540 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Extra simplex iterations after uncrush: 2
#
# Root relaxation: objective 1.330655e+02, 376 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  133.06553    0  162   -0.00000  133.06553      -     -    0s
# H    0     0                      19.0000000  133.06553   600%     -    0s
# H    0     0                      26.0000000  133.06553   412%     -    0s
#      0     0   94.53890    0  135   26.00000   94.53890   264%     -    0s
#      0     0   94.53890    0  118   26.00000   94.53890   264%     -    0s
#      0     0   93.03431    0  138   26.00000   93.03431   258%     -    0s
#      0     0   90.74091    0  142   26.00000   90.74091   249%     -    0s
#      0     0   76.92157    0  141   26.00000   76.92157   196%     -    0s
#      0     0   73.49894    0  142   26.00000   73.49894   183%     -    0s
#      0     0   72.44166    0  145   26.00000   72.44166   179%     -    0s
#      0     0   72.10929    0  146   26.00000   72.10929   177%     -    0s
#      0     0   71.94542    0  145   26.00000   71.94542   177%     -    0s
#      0     0   71.77383    0  146   26.00000   71.77383   176%     -    0s
#      0     0   71.65121    0  143   26.00000   71.65121   176%     -    0s
#      0     0   71.63768    0  146   26.00000   71.63768   176%     -    0s
#      0     0   71.61179    0  145   26.00000   71.61179   175%     -    0s
#      0     0   71.60662    0  146   26.00000   71.60662   175%     -    0s
#      0     0   66.57760    0  146   26.00000   66.57760   156%     -    0s
.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0xaff9dd73
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 280 rows and 160 columns
# Presolve time: 0.01s
# Presolved: 1881 rows, 580 columns, 12140 nonzeros
# Variable types: 380 continuous, 200 integer (200 binary)
# Root relaxation presolved: 1701 rows, 760 columns, 8540 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Extra simplex iterations after uncrush: 1
#
# Root relaxation: objective 1.136917e+02, 295 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  113.69171    0  172   -0.00000  113.69171      -     -    0s
# H    0     0                       8.0000000  113.69171  1321%     -    0s
# H    0     0                      11.0000000  113.69171   934%     -    0s
#      0     0   42.17858    0   60   11.00000   42.17858   283%     -    0s
#      0     0   42.17858    0   60   11.00000   42.17858   283%     -    0s
# H    0     0                      16.0000000   42.17858   164%     -    0s
# H    0     0                      18.0000000   42.17858   134%     -    0s
#      0     0   41.95100    0   65   18.00000   41.95100   133%     -    0s
#      0     0   40.43215    0   64   18.00000   40.43215   125%     -    0s
#      0     0   35.78957    0   65   18.00000   35.78957  98.8%     -    0s
#      0     0   34.48087    0   69   18.00000   34.48087  91.6%     -    0s
#      0     0   31.12473    0   73   18.00000   31.12473  72.9%     -    0s
#      0     0   30.59589    0   69   18.00000   30.59589  70.0%     -    0s
#      0     0   30.28954    0   73   18.00000   30.28954  68.3%     -    0s
#      0     0   29.89985    0   70   18.00000   29.89985  66.1%     -    0s
#      0     0   29.10418    0   65   18.00000   29.10418  61.7%     -    0s
#      0     0   28.08453    0   70   18.00000   28.08453  56.0%     -    0s
#      0     0   27.91127    0   69   18.00000   27.91127  55.1%     -    0s
#      0     0   27.64219    0   66   18.00000   27.64219  53.6%     -    0s
#      0     0   27.49746    0   68   18.00000   27.49746  52.8%     -    0s
#      0     0   27.44370    0   73   18.00000   27.44370  52.5%     -    0s
#      0     0   27.09144    0   73   18.00000   27.09144  50.5%     -    0s
#      0     0   27.09144    0   70   18.00000   27.09144  50.5%     -    0s
#      0     0   27.03706    0   69   18.00000   27.03706  50.2%     -    0s
#      0     0   26.91851    0   72   18.00000   26.91851  49.5%     -    0s
#      0     0   26.85816    0   73   18.00000   26.85816  49.2%     -    0s
#      0     0   26.79934    0   72   18.00000   26.79934  48.9%     -    0s
#      0     0   26.79414    0   72   18.00000   26.79414  48.9%     -    0s
#      0     0   26.77595    0   75   18.00000   26.77595  48.8%     -    0s
#      0     0   26.57906    0   68   18.00000   26.57906  47.7%     -    0s
#      0     0   26.49440    0   73   18.00000   26.49440  47.2%     -    0s
#      0     0   26.34130    0   73   18.00000   26.34130  46.3%     -    0s
#      0     0   26.05499    0   71   18.00000   26.05499  44.7%     -    0s
#      0     0   26.05499    0   71   18.00000   26.05499  44.7%     -    0s
#      0     0   26.04161    0   71   18.00000   26.04161  44.7%     -    0s
#      0     0   26.00752    0   71   18.00000   26.00752  44.5%     -    0s
#      0     0   25.98778    0   71   18.00000   25.98778  44.4%     -    0s
#      0     0   25.96058    0   71   18.00000   25.96058  44.2%     -    0s
#      0     0   25.95394    0   71   18.00000   25.95394  44.2%     -    0s
#      0     0   25.90542    0   73   18.00000   25.90542  43.9%     -    0s
#      0     0   25.51315    0   66   18.00000   25.51315  41.7%     -    0s
#      0     0   25.15433    0   66   18.00000   25.15433  39.7%     -    0s
#      0     2   25.15433    0   66   18.00000   25.15433  39.7%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 35
#   MIR: 42
#   StrongCG: 9
#   RLT: 1
#
# Explored 62 nodes (3219 simplex iterations) in 0.38 seconds (0.71 work units)
# Thread count was 2 (of 24 available processors)
#
# Solution count 5: 18 16 11 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
#
# User-callback calls 819, time in user-callback 0.00 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0xd4385e0d
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 2e+01]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 280 rows and 160 columns
# Presolve time: 0.01s
# Presolved: 1881 rows, 580 columns, 12140 nonzeros
# Variable types: 380 continuous, 200 integer (200 binary)
# Root relaxation presolved: 1701 rows, 760 columns, 8540 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 9.397096e+01, 391 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   93.97096    0  179   -0.00000   93.97096      -     -    0s
# H    0     0                       3.0000000   93.97096  3032%     -    0s
# H    0     0                       4.0000000   93.97096  2249%     -    0s
# H    0     0                       5.0000000   93.97096  1779%     -    0s
#      0     0   55.34826    0  111    5.00000   55.34826  1007%     -    0s
#      0     0   55.34826    0  103    5.00000   55.34826  1007%     -    0s
# H    0     0                       6.0000000   55.34826   822%     -    0s
#      0     0   32.77312    0   63    6.00000   32.77312   446%     -    0s
# H    0     0                       9.0000000   31.90203   254%     -    0s
# H    0     0                      11.0000000   31.90203   190%     -    0s
#      0     0   31.90203    0   65   11.00000   31.90203   190%     -    0s
#      0     0   27.40949    0   71   11.00000   27.40949   149%     -    0s
     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 3
#   MIR: 8
#   Flow cover: 6
#   Inf proof: 1
#   RLT: 13
#
# Explored 9522 nodes (179904 simplex iterations) in 4.13 seconds (12.39 work units)
# Thread count was 2 (of 24 available processors)
#
# Solution count 5: 153 143 131 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.530000000000e+02, best bound 1.530000000000e+02, gap 0.0000%
#
# User-callback calls 21333, time in user-callback 0.01 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0x4b1c616d
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 8e+00]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 280 rows and 160 columns
# Presolve time: 0.02s
# Presolved: 1881 rows, 580 columns, 12140 nonzeros
# Variable types: 380 continuous, 200 integer (200 binary)
# Root relaxation presolved: 1701 rows, 760 columns, 8540 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Extra simplex iterations after uncrush: 25
#
# Root relaxation: objective 1.800000e+02, 543 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  180.00000    0    7   -0.00000  180.00000      -     -    0s
# H    0     0                       7.0000000  180.00000  2471%     -    0s
# H    0     0                      22.0000000  180.00000   718%     -    0s
#      0     0  180.00000    0   10   22.00000  180.00000   718%     -    0s
#      0     0  180.00000    0    7   22.00000  180.00000   718%     -    0s
# H    0     0                      54.0000000  180.00000   233%     -    0s
# H    0     0                     161.0000000  180.00000  11.8%     -    0s
#      0     0  179.98050    0   17  161.00000  179.98050  11.8%     -    0s
#      0     0  179.90134    0   22  161.00000  179.90134  11.7%     -    0s
#      0     0  179.79683    0   27  161.00000  179.79683  11.7%     -    0s
#      0     0  179.69555    0   28  161.00000  179.69555  11.6%     -    0s
#      0     0  179.29724    0   48  161.00000  179.29724  11.4%     -    0s
#      0     0  179.04272    0   55  161.00000  179.04272  11.2%     -    0s
#      0     0  178.53432    0   64  161.00000  178.53432  10.9%     -    0s
#      0     0  178.34611    0   65  161.00000  178.34611  10.8%     -    0s
#      0     0  178.34611    0   69  161.00000  178.34611  10.8%     -    0s
#      0     0  178.34611    0   72  161.00000  178.34611  10.8%     -    0s
#      0     0  178.34611    0   71  161.00000  178.34611  10.8%     -    0s
#      0     0  178.34611    0   73  161.00000  178.34611  10.8%     -    0s
#      0     0  178.34611    0   74  161.00000  178.34611  10.8%     -    0s
#      0     0  178.19602    0   78  161.00000  178.19602  10.7%     -    0s
#      0     0  178.19602    0   77  161.00000  178.19602  10.7%     -    0s
#      0     0  178.19602    0   75  161.00000  178.19602  10.7%     -    0s
#      0     0  178.19602    0   73  161.00000  178.19602  10.7%     -    0s
#      0     0  178.19602    0   75  161.00000  178.19602  10.7%     -    0s
#      0     0  178.19602    0   75  161.00000  178.19602  10.7%     -    0s
#      0     0  178.19602    0   74  161.00000  178.19602  10.7%     -    0s
#      0     0  178.19602    0   73  161.00000  178.19602  10.7%     -    0s
#      0     0  178.19602    0   76  161.00000  178.19602  10.7%     -    0s
#      0     0  178.19602    0   76  161.00000  178.19602  10.7%     -    0s
#      0     0  178.19602    0   76  161.00000  178.19602  10.7%     -    0s
#      0     2  178.14767    0   76  161.00000  178.14767  10.7%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 163
#   MIR: 112
#   StrongCG: 60
#   Inf proof: 2
#   RLT: 8
#
# Explored 2833 nodes (82175 simplex iterations) in 1.59 seconds (5.63 work units)
# Thread count was 2 (of 24 available processors)
#
# Solution count 5: 161 54 22 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.610000000000e+02, best bound 1.610000000000e+02, gap 0.0000%
#
# User-callback calls 6449, time in user-callback 0.01 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0x45d8ef43
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 8e+00]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 280 rows and 160 columns
# Presolve time: 0.01s
# Presolved: 1881 rows, 580 columns, 12140 nonzeros
# Variable types: 380 continuous, 200 integer (200 binary)
# Root relaxation presolved: 1701 rows, 760 columns, 8540 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Extra simplex iterations after uncrush: 4
#
# Root relaxation: objective 1.657629e+02, 483 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  165.76288    0  160   -0.00000  165.76288      -     -    0s
# H    0     0                      14.0000000  165.76288  1084%     -    0s
# H    0     0                      30.0000000  165.76288   453%     -    0s
#      0     0  156.09848    0  161   30.00000  156.09848   420%     -    0s
#      0     0  156.09848    0  159   30.00000  156.09848   420%     -    0s
#      0     0  156.09848    0  161   30.00000  156.09848   420%     -    0s
# H    0     0                      54.0000000  156.01008   189%     -    0s
#      0     0  155.70945    0  164   54.00000  155.70945   188%     -    0s
#      0     0  152.41575    0  172   54.00000  152.41575   182%     -    0s
#      0     0  151.18951    0  172   54.00000  151.18951   180%     -    0s
#      0     0  147.34073    0  174   54.00000  147.34073   173%     -    0s
#      0     0  147.07067    0  176   54.00000  147.07067   172%     -    0s
#      0     0  145.56722    0  177   54.00000  145.56722   170%     -    0s
#      0     0  145.19577    0  181   54.00000  145.19577   169%     -    0s
#      0     0  145.02034    0  181   54.00000  145.02034   169%     -    0s
#      0     0  144.98705    0  181   54.00000  144.98705   168%     -    0s
#      0     0  144.85316    0  181   54.00000  144.85316   168%     -    0s
#      0     0  144.82483    0  181   54.00000  144.82483   168%     -    0s
#      0     0  144.78530    0  180   54.00000  144.78530   168%     -    0s
#      0     0  144.74420    0  181   54.00000  144.74420   168%     -    0s
#      0     0  144.67007    0  180   54.00000  144.67007   168%     -    0s
#      0     0  144.62058    0  181   54.00000  144.62058   168%     -    0s
#      0     0  144.62058    0  181   54.00000  144.62058   168%     -    0s
#      0     0  144.55375    0  181   54.00000  144.55375   168%     -    0s
#      0     0  144.47626    0  181   54.00000  144.47626   168%     -    0s
#      0     0  144.47626    0  181   54.00000  144.47626   168%     -    0s
#      0     0  144.45278    0  181   54.00000  144.45278   168%     -    0s
#      0     0  144.45278    0  181   54.00000  144.45278   168%     -    0s
#      0     0  144.45278    0  181   54.00000  144.45278   168%     -    0s
#      0     2  144.45278    0  181   54.00000  144.45278   168%     -    0s
# H  506   271                      55.0000000  141.67327   158%  12.6    0s
# H  679   335                      65.0000000  141.67327   118%  11.9    0s
#   8729  3402   87.34689   30   73   65.00000  105.75076  62.7%  16.4    5s
#  16639   720 infeasible   49        65.00000   74.01065  13.9%  20.6   10s
#
# Cutting planes:
#   Gomory: 27
#   Cover: 84
#   Clique: 1
#   MIR: 132
#   StrongCG: 27
#   Flow cover: 30
#   Inf proof: 36
#   RLT: 19
#
# Explored 17730 nodes (358316 simplex iterations) in 10.24 seconds (28.86 work units)
# Thread count was 2 (of 24 available processors)
#
# Solution count 6: 65 55 54 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
#
# User-callback calls 41091, time in user-callback 0.03 sec
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010', '0.0010']
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Set parameter MIPGapAbs to value 0.99
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 2161 rows, 740 columns and 13220 nonzeros
# Model fingerprint: 0x66bdb04c
# Variable types: 480 continuous, 260 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 1e+00]
#   RHS range        [1e-03, 8e+00]
#
# Loaded user MIP start with objective -0
#
# Loaded user MIP start with objective -0
#
# Presolve removed 280 rows and 160 columns
# Presolve time: 0.01s
# Presolved: 1881 rows, 580 columns, 12140 nonzeros
# Variable types: 380 continuous, 200 integer (200 binary)
# Root relaxation presolved: 1701 rows, 760 columns, 8540 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Extra simplex iterations after uncrush: 87
#
# Root relaxation: objective 1.798986e+02, 521 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0