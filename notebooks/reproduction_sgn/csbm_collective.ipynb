# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

def prepare():
    module_path = os.path.abspath(os.path.join('../', '../'))
    if module_path not in sys.path:
        sys.path.append(module_path)

print(sys.path)

# %%
import torch
import numpy as np
prepare()
from exp_labelcert_collective import run
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       2 import numpy as np
#       3 prepare()
# ----> 4 from exp_labelcert_collective import run
#
# ModuleNotFoundError: No module named 'exp_labelcert_collective'

# %%
seeds = [0, 1, 2, 3, 4]
deltas = [0.00, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30]

# %%
model_params = dict(
    label = "SGC", 
    model = "GCN", 
    normalization = "row_normalization",
    activation = "linear",
    depth = 1,
    regularizer = 0.001,
    pred_method = "svm",
    bias = False,
    alpha_tol = 1e-4,
    solver = "qplayer",
)

certificate_params = dict(
    delta = 0.01,
    TimeLimit = 86400,
    LogToConsole = 1,
    OutputFlag = 1,
    Threads = 2,
    Presolve = 2
)

verbosity_params = dict(
    debug_lvl = "warning"
)  

other_params = dict(
    device = "0",
    dtype = torch.float64,
    allow_tf32 = False,
    path_gurobi_license="/mnt/c/Users/emiel/gurobi.lic"
)

# %%
data_params = dict(
    dataset = "csbm",
    learning_setting = "transductive", 
    specification = dict(
        classes = 2,
        n_trn_labeled = 10,
        n_trn_unlabeled = 0,
        n_val = 10,
        n_test = 180,
        sigma = 1,
        avg_within_class_degree = 1.58 * 2,
        avg_between_class_degree = 0.37 * 2,
        K = 1.5,
        # seed = 0 # used to generate the dataset & data split
    )
)

# %%
import pandas as pd
import time

metrics_to_log = ["accuracy_test", "accuracy_trn", "accuracy_cert_pois_robust", "delta", "runtime"]
output_base_dir = "results/collective"
os.makedirs(output_base_dir, exist_ok=True)

dataset_name = "csbm"

for delta in deltas:
    certificate_params["delta"] = delta
    summary_results = []
    print(f"  Running for delta: {delta:.2f}")

    for seed in seeds:
        data_params["specification"]["seed"] = seed
        start_time = time.time()
        result = run(data_params=data_params, model_params=model_params,
                     certificate_params=certificate_params, verbosity_params=verbosity_params,
                     other_params=other_params, seed=seed)
        runtime = round(time.time() - start_time, 2)
        result['runtime'] = runtime
        summary_results.append({k: result.get(k) for k in metrics_to_log})

    df = pd.DataFrame(summary_results, index=[f"Seed {s}" for s in seeds])
    df.index.name = "seed"
    output_filename = f"{dataset_name}-{delta:.2f}.csv"
    output_path = os.path.join(output_base_dir, output_filename)
    df.to_csv(output_path, index=True)

    print(f"  Results saved to: {output_path}")
    print(df)
    print("-" * 30)
# Out:
#   Running for delta: 0.00
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# 20 alphas found: ['0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100', '0.0100']
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2676106
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xa0e13c79
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [6e-02, 5e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.267089
#
# Loaded user MIP start with objective -0.267089
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.267089 -0.267089
# No other solutions better than -0.267089
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.670887712242e-01, best bound -2.670887712242e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x21020db5
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [3e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.17259
#
# Loaded user MIP start with objective -0.17259
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.17259 -0.17259
# No other solutions better than -0.17259
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.725901343098e-01, best bound -1.725901343098e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x1a9bae50
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [4e-02, 1e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.113707
#
# Loaded user MIP start with objective -0.113707
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.113707 -0.113707
# No other solutions better than -0.113707
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.137069296497e-01, best bound -1.137069296497e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x09389225
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [4e-02, 3e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.148404
#
# Loaded user MIP start with objective -0.148404
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.148404 -0.148404
# No other solutions better than -0.148404
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.484042685504e-01, best bound -1.484042685504e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x8c824cd8
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [1e-02, 8e-01]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.0296798
#
# Loaded user MIP start with objective -0.0296798
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.0296798 -0.0296798
# No other solutions better than -0.0296798
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.967982081982e-02, best bound -2.967982081982e-02, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xc8bd0b4c
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [6e-02, 3e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.10294
#
# Loaded user MIP start with objective -0.10294
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.10294 -0.10294
# No other solutions better than -0.10294
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.029399856030e-01, best bound -1.029399856030e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x8d958435
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [3e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.135369
#
# Loaded user MIP start with objective -0.135369
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.135369 -0.135369
# No other solutions better than -0.135369
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.353688500096e-01, best bound -1.353688500096e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xbb182516
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [2e-02, 7e-01]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.0441183
#
# Loaded user MIP start with objective -0.0441183
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.0441183 -0.0441183
# No other solutions better than -0.0441183
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.411831954807e-02, best bound -4.411831954807e-02, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x6e6305a0
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [8e-02, 4e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.219877
#
# Loaded user MIP start with objective -0.219877
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.219877 -0.219877
# No other solutions better than -0.219877
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.198768915350e-01, best bound -2.198768915350e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x459c4002
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [1e-01, 4e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.309254
#
# Loaded user MIP start with objective -0.309254
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.309254 -0.309254
# No other solutions better than -0.309254
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.092540043645e-01, best bound -3.092540043645e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x69695e5f
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [2e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.137846
#
# Loaded user MIP start with objective -0.137846
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.137846 -0.137846
# No other solutions better than -0.137846
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.378457838833e-01, best bound -1.378457838833e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xaa31386f
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [6e-02, 1e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective 0.09195
#
# Loaded user MIP start with objective 0.09195
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: 0.09195 0.09195
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.194995379736e-02, best bound 9.194995379736e-02, gap 0.0000%
#
# User-callback calls 172, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xd92a4e11
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [1e-01, 3e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.264522
#
# Loaded user MIP start with objective -0.264522
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.264522 -0.264522
# No other solutions better than -0.264522
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.645223963823e-01, best bound -2.645223963823e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xa240b32b
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [3e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective 0.053797
#
# Loaded user MIP start with objective 0.053797
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: 0.053797 0.053797
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.379699143944e-02, best bound 5.379699143944e-02, gap 0.0000%
#
# User-callback calls 172, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x1f526bd8
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [9e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.168924
#
# Loaded user MIP start with objective -0.168924
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.168924 -0.168924
# No other solutions better than -0.168924
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.689235713097e-01, best bound -1.689235713097e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xb095a70b
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.181859
#
# Loaded user MIP start with objective -0.181859
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.181859 -0.181859
# No other solutions better than -0.181859
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.818590112585e-01, best bound -1.818590112585e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x89d4f4ef
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [1e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.0923448
#
# Loaded user MIP start with objective -0.0923448
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.0923448 -0.0923448
# No other solutions better than -0.0923448
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -9.234476925771e-02, best bound -9.234476925771e-02, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x86e0ebc5
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [5e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.180321
#
# Loaded user MIP start with objective -0.180321
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.180321 -0.180321
# No other solutions better than -0.180321
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.803208159840e-01, best bound -1.803208159840e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x377cbf26
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [1e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.0128729
#
# Loaded user MIP start with objective -0.0128729
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.0128729 -0.0128729
# No other solutions better than -0.0128729
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.287289086375e-02, best bound -1.287289086375e-02, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x48c77670
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.0939685
#
# Loaded user MIP start with objective -0.0939685
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.0939685 -0.0939685
# No other solutions better than -0.0939685
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -9.396846851130e-02, best bound -9.396846851130e-02, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xc28092ac
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [1e-01, 6e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.46851
#
# Loaded user MIP start with objective -0.46851
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.46851 -0.46851
# No other solutions better than -0.46851
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.685097427481e-01, best bound -4.685097427481e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xbdaf551d
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [1e-01, 3e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.185716
#
# Loaded user MIP start with objective -0.185716
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.185716 -0.185716
# No other solutions better than -0.185716
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.857164387287e-01, best bound -1.857164387287e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xd739b124
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [2e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.110324
#
# Loaded user MIP start with objective -0.110324
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.110324 -0.110324
# No other solutions better than -0.110324
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.103244276972e-01, best bound -1.103244276972e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x431f1a9e
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [8e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.173362
#
# Loaded user MIP start with objective -0.173362
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.173362 -0.173362
# No other solutions better than -0.173362
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.733620367046e-01, best bound -1.733620367046e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x261d1a4f
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [2e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.0962724
#
# Loaded user MIP start with objective -0.0962724
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.0962724 -0.0962724
# No other solutions better than -0.0962724
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -9.627235355776e-02, best bound -9.627235355776e-02, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xafc25dd3
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [8e-03, 1e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective 0.0399041
#
# Loaded user MIP start with objective 0.0399041
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: 0.0399041 0.0399041
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.990408096843e-02, best bound 3.990408096843e-02, gap 0.0000%
#
# User-callback calls 172, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xb20db3ec
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [2e-01, 4e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.253081
#
# Loaded user MIP start with objective -0.253081
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.253081 -0.253081
# No other solutions better than -0.253081
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.530807973728e-01, best bound -2.530807973728e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x12a23df2
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [1e-01, 4e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.33456
#
# Loaded user MIP start with objective -0.33456
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.33456 -0.33456
# No other solutions better than -0.33456
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.345602471148e-01, best bound -3.345602471148e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x8879b3d3
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+03]
#   Objective range  [8e-03, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.100699
#
# Loaded user MIP start with objective -0.100699
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.100699 -0.100699
# No other solutions better than -0.100699
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.006993238691e-01, best bound -1.006993238691e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# ...
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xfa54e70b
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+03]
#   Objective range  [2e-02, 1e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective 0.00614883
#
# Loaded user MIP start with objective 0.00614883
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 1: 0.00614883
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.148825151859e-03, best bound 6.148825151859e-03, gap 0.0000%
#
# User-callback calls 171, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xcf1c70d2
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+03]
#   Objective range  [8e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.0752102
#
# Loaded user MIP start with objective -0.0752102
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.0752102 -0.0752102
# No other solutions better than -0.0752102
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -7.521015703713e-02, best bound -7.521015703713e-02, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xb844d192
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+03]
#   Objective range  [1e-02, 6e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.342106
#
# Loaded user MIP start with objective -0.342106
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.342105 -0.342106
# No other solutions better than -0.342105
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.421054983782e-01, best bound -3.421054983782e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x1ed95ba5
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+03]
#   Objective range  [4e-03, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.0600896
#
# Loaded user MIP start with objective -0.0600896
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.0600896 -0.0600896
# No other solutions better than -0.0600896
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.008957478552e-02, best bound -6.008957478552e-02, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x139ef8d3
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+03]
#   Objective range  [4e-02, 4e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.0793268
#
# Loaded user MIP start with objective -0.0793268
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.0793268 -0.0793268
# No other solutions better than -0.0793268
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -7.932676448219e-02, best bound -7.932676448219e-02, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xcf6d8f2a
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+03]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.134666
#
# Loaded user MIP start with objective -0.134666
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.134666 -0.134666
# No other solutions better than -0.134666
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.346662658037e-01, best bound -1.346662658037e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x7bcafaba
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+03]
#   Objective range  [1e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.0788381
#
# Loaded user MIP start with objective -0.0788381
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.0788381 -0.0788381
# No other solutions better than -0.0788381
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -7.883807502673e-02, best bound -7.883807502673e-02, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xf8031fde
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+03]
#   Objective range  [5e-02, 3e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.169505
#
# Loaded user MIP start with objective -0.169505
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.169505 -0.169505
# No other solutions better than -0.169505
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.695048274134e-01, best bound -1.695048274134e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0xfea62c69
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+03]
#   Objective range  [3e-02, 2e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.00161336
#
# Loaded user MIP start with objective -0.00161336
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.00161336 -0.00161336
# No other solutions better than -0.00161336
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.613356802290e-03, best bound -1.613356802290e-03, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
# Set parameter Presolve to value 2
# Set parameter Threads to value 2
# Set parameter FeasibilityTol to value 0.0001
# Set parameter OptimalityTol to value 0.0001
# Set parameter TimeLimit to value 86400
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700K, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 24 logical processors, using up to 2 threads
#
# Academic license 2676106 - for non-commercial use only - registered to eg___@tudelft.nl
# Optimize a model with 1801 rows, 560 columns and 5660 nonzeros
# Model fingerprint: 0x4cbdce0a
# Variable types: 500 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+03]
#   Objective range  [1e-01, 3e+00]
#   Bounds range     [1e-02, 1e+00]
#   RHS range        [1e-02, 2e+01]
#
# Loaded user MIP start with objective -0.102627
#
# Loaded user MIP start with objective -0.102627
#
# Presolve removed 1801 rows and 560 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 24 available processors)
#
# Solution count 2: -0.102627 -0.102627
# No other solutions better than -0.102627
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.026268987008e-01, best bound -1.026268987008e-01, gap 0.0000%
#
# User-callback calls 173, time in user-callback 0.00 sec
# Set parameter BestObjStop to value 0
# Set parameter BestBdStop to value 0
# Set parameter IntegralityFocus to value 1
# Set parameter IntFeasTol to value 0.0001
# Set parameter DualReductions to value 0
